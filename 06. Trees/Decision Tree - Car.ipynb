# %%
car_data = "https://archive.ics.uci.edu/ml/machine-learning-databases/car/car.data"

# %%
import pandas as pd
pd.read_csv(car_data, header=None)
# Out:
#           0      1      2     3      4     5      6
# 0     vhigh  vhigh      2     2  small   low  unacc
# 1     vhigh  vhigh      2     2  small   med  unacc
# 2     vhigh  vhigh      2     2  small  high  unacc
# 3     vhigh  vhigh      2     2    med   low  unacc
# 4     vhigh  vhigh      2     2    med   med  unacc
# ...     ...    ...    ...   ...    ...   ...    ...
# 1723    low    low  5more  more    med   med   good
# 1724    low    low  5more  more    med  high  vgood
# 1725    low    low  5more  more    big   low  unacc
# 1726    low    low  5more  more    big   med   good
# 1727    low    low  5more  more    big  high  vgood
#
# [1728 rows x 7 columns]

# %%
columns =["Buying",
"Maintaince",
"Doors",
"Persons",
"Lug_boot",
"Safety","Class_value"]

# %%
df = pd.read_csv(car_data, names=columns)

# %%
df.dtypes
# Out:
# Buying         object
# Maintaince     object
# Doors          object
# Persons        object
# Lug_boot       object
# Safety         object
# Class_value    object
# dtype: object

# %%
df
# Out:
#      Buying Maintaince  Doors Persons Lug_boot Safety Class_value
# 0     vhigh      vhigh      2       2    small    low       unacc
# 1     vhigh      vhigh      2       2    small    med       unacc
# 2     vhigh      vhigh      2       2    small   high       unacc
# 3     vhigh      vhigh      2       2      med    low       unacc
# 4     vhigh      vhigh      2       2      med    med       unacc
# ...     ...        ...    ...     ...      ...    ...         ...
# 1723    low        low  5more    more      med    med        good
# 1724    low        low  5more    more      med   high       vgood
# 1725    low        low  5more    more      big    low       unacc
# 1726    low        low  5more    more      big    med        good
# 1727    low        low  5more    more      big   high       vgood
#
# [1728 rows x 7 columns]

# %%
df.shape
# Out:
# (1728, 7)

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1728 entries, 0 to 1727
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Buying       1728 non-null   object
#  1   Maintaince   1728 non-null   object
#  2   Doors        1728 non-null   object
#  3   Persons      1728 non-null   object
#  4   Lug_boot     1728 non-null   object
#  5   Safety       1728 non-null   object
#  6   Class_value  1728 non-null   object
# dtypes: object(7)
# memory usage: 94.6+ KB
# Buying         0
# Maintaince     0
# Doors          0
# Persons        0
# Lug_boot       0
# Safety         0
# Class_value    0
# dtype: int64

# %%
X, y = df.iloc[:, :-1], df.iloc[:, -1]

# %%
X
# Out:
#      Buying Maintaince  Doors Persons Lug_boot Safety
# 0     vhigh      vhigh      2       2    small    low
# 1     vhigh      vhigh      2       2    small    med
# 2     vhigh      vhigh      2       2    small   high
# 3     vhigh      vhigh      2       2      med    low
# 4     vhigh      vhigh      2       2      med    med
# ...     ...        ...    ...     ...      ...    ...
# 1723    low        low  5more    more      med    med
# 1724    low        low  5more    more      med   high
# 1725    low        low  5more    more      big    low
# 1726    low        low  5more    more      big    med
# 1727    low        low  5more    more      big   high
#
# [1728 rows x 6 columns]

# %%
y
# Out:
# 0       unacc
# 1       unacc
# 2       unacc
# 3       unacc
# 4       unacc
#         ...
# 1723     good
# 1724    vgood
# 1725    unacc
# 1726     good
# 1727    vgood
# Name: Class_value, Length: 1728, dtype: object

# %%
import matplotlib.pyplot as plt
for col_name in df.columns:
        plt.figure()
        plt.hist(df[col_name])
        plt.title(col_name)

# %%
for col_name in df.columns:
    print(df[col_name].value_counts())
# Out:
# vhigh    432
# high     432
# low      432
# med      432
# Name: Buying, dtype: int64
# vhigh    432
# high     432
# low      432
# med      432
# Name: Maintaince, dtype: int64
# 2        432
# 3        432
# 5more    432
# 4        432
# Name: Doors, dtype: int64
# 2       576
# 4       576
# more    576
# Name: Persons, dtype: int64
# small    576
# big      576
# med      576
# Name: Lug_boot, dtype: int64
# high    576
# low     576
# med     576
# Name: Safety, dtype: int64
# unacc    1210
# acc       384
# good       69
# vgood      65
# Name: Class_value, dtype: int64

# %%
df['Class_value'].value_counts()
# Out:
# unacc    1210
# acc       384
# good       69
# vgood      65
# Name: Class_value, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.3,stratify=y)

# %%
X_train.shape, X_test.shape
# Out:
# ((1209, 6), (519, 6))

# %%
from sklearn.preprocessing import OrdinalEncoder
le = OrdinalEncoder()
X_train = le.fit_transform(X_train)
X_test = le.transform(X_test)

# %%
X_test
# Out:
# array([[1., 3., 1., 2., 0., 0.],
#        [2., 2., 2., 0., 0., 0.],
#        [2., 1., 0., 2., 0., 0.],
#        ...,
#        [2., 1., 1., 1., 2., 0.],
#        [3., 2., 3., 1., 1., 2.],
#        [0., 3., 0., 2., 0., 0.]])

# %%
dt_clf = DecisionTreeClassifier(criterion='gini',random_state=42,max_depth=12)
dt_clf = dt_clf.fit(X_train, y_train)

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(100, 50))
plot_tree(dt_clf,
          filled=True,
          rounded=True,
          class_names=["Buying",
"Maintaince",
"Doors",
"Persons",
"Lug_boot",
"Safety"],
         feature_names=X.columns)
# Out:
# [Text(3185.8783783783783, 2613.4615384615386, 'Persons <= 0.5\ngini = 0.457\nsamples = 1209\nvalue = [269, 48, 847, 45]\nclass = Doors'),
#  Text(3110.472972972973, 2404.3846153846152, 'gini = 0.0\nsamples = 404\nvalue = [0, 0, 404, 0]\nclass = Doors'),
#  Text(3261.2837837837837, 2404.3846153846152, 'Safety <= 0.5\ngini = 0.579\nsamples = 805\nvalue = [269, 48, 443, 45]\nclass = Doors'),
#  Text(1865.1055743243244, 2195.3076923076924, 'Maintaince <= 2.5\ngini = 0.634\nsamples = 271\nvalue = [144, 22, 60, 45]\nclass = Buying'),
#  Text(1015.6165540540541, 1986.2307692307693, 'Buying <= 0.5\ngini = 0.625\nsamples = 215\nvalue = [118, 22, 30, 45]\nclass = Buying'),
#  Text(226.2162162162162, 1777.1538461538462, 'Doors <= 0.5\ngini = 0.101\nsamples = 56\nvalue = [53, 0, 3, 0]\nclass = Buying'),
#  Text(150.8108108108108, 1568.076923076923, 'Lug_boot <= 1.5\ngini = 0.278\nsamples = 18\nvalue = [15, 0, 3, 0]\nclass = Buying'),
#  Text(75.4054054054054, 1359.0, 'gini = 0.0\nsamples = 12\nvalue = [12, 0, 0, 0]\nclass = Buying'),
#  Text(226.2162162162162, 1359.0, 'Persons <= 1.5\ngini = 0.5\nsamples = 6\nvalue = [3, 0, 3, 0]\nclass = Buying'),
#  Text(150.8108108108108, 1149.923076923077, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = Buying'),
#  Text(301.6216216216216, 1149.923076923077, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]\nclass = Doors'),
#  Text(301.6216216216216, 1568.076923076923, 'gini = 0.0\nsamples = 38\nvalue = [38, 0, 0, 0]\nclass = Buying'),
#  Text(1805.0168918918919, 1777.1538461538462, 'Buying <= 2.5\ngini = 0.705\nsamples = 159\nvalue = [65, 22, 27, 45]\nclass = Buying'),
#  Text(1197.0608108108108, 1568.076923076923, 'Lug_boot <= 1.5\ngini = 0.677\nsamples = 107\nvalue = [34, 22, 6, 45]\nclass = Persons'),
#  Text(678.6486486486486, 1359.0, 'Maintaince <= 0.5\ngini = 0.496\nsamples = 68\nvalue = [16, 7, 0, 45]\nclass = Persons'),
#  Text(452.4324324324324, 1149.923076923077, 'Buying <= 1.5\ngini = 0.463\nsamples = 22\nvalue = [14, 0, 0, 8]\nclass = Buying'),
#  Text(377.02702702702703, 940.846153846154, 'Lug_boot <= 0.5\ngini = 0.397\nsamples = 11\nvalue = [3, 0, 0, 8]\nclass = Persons'),
#  Text(301.6216216216216, 731.769230769231, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5]\nclass = Persons'),
#  Text(452.4324324324324, 731.769230769231, 'Doors <= 0.5\ngini = 0.5\nsamples = 6\nvalue = [3, 0, 0, 3]\nclass = Buying'),
#  Text(377.02702702702703, 522.6923076923076, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Buying'),
#  Text(527.8378378378378, 522.6923076923076, 'Persons <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 0, 3]\nclass = Persons'),
#  Text(452.4324324324324, 313.61538461538476, 'Doors <= 2.0\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = Buying'),
#  Text(377.02702702702703, 104.53846153846189, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Buying'),
#  Text(527.8378378378378, 104.53846153846189, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Persons'),
#  Text(603.2432432432432, 313.61538461538476, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = Persons'),
#  Text(527.8378378378378, 940.846153846154, 'gini = 0.0\nsamples = 11\nvalue = [11, 0, 0, 0]\nclass = Buying'),
#  Text(904.8648648648648, 1149.923076923077, 'Doors <= 0.5\ngini = 0.328\nsamples = 46\nvalue = [2, 7, 0, 37]\nclass = Persons'),
#  Text(678.6486486486486, 940.846153846154, 'Lug_boot <= 0.5\ngini = 0.615\nsamples = 13\nvalue = [2, 5, 0, 6]\nclass = Persons'),
#  Text(603.2432432432432, 731.769230769231, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6]\nclass = Persons'),
#  Text(754.0540540540541, 731.769230769231, 'Buying <= 1.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5, 0, 0]\nclass = Maintaince'),
#  Text(678.6486486486486, 522.6923076923076, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]\nclass = Maintaince'),
#  Text(829.4594594594595, 522.6923076923076, 'Maintaince <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1, 0, 0]\nclass = Buying'),
#  Text(754.0540540540541, 313.61538461538476, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Maintaince'),
#  Text(904.8648648648648, 313.61538461538476, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Buying'),
#  Text(1131.081081081081, 940.846153846154, 'Doors <= 1.5\ngini = 0.114\nsamples = 33\nvalue = [0, 2, 0, 31]\nclass = Persons'),
#  Text(1055.6756756756756, 731.769230769231, 'Lug_boot <= 0.5\ngini = 0.298\nsamples = 11\nvalue = [0, 2, 0, 9]\nclass = Persons'),
#  Text(980.2702702702702, 522.6923076923076, 'gini = 0.0\nsamples = 8\nvalue = [0, 0, 0, 8]\nclass = Persons'),
#  Text(1131.081081081081, 522.6923076923076, 'Persons <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 1]\nclass = Maintaince'),
#  Text(1055.6756756756756, 313.61538461538476, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = Maintaince'),
#  Text(1206.4864864864865, 313.61538461538476, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Persons'),
#  Text(1206.4864864864865, 731.769230769231, 'gini = 0.0\nsamples = 22\nvalue = [0, 0, 0, 22]\nclass = Persons'),
#  Text(1715.472972972973, 1359.0, 'Maintaince <= 0.5\ngini = 0.615\nsamples = 39\nvalue = [18, 15, 6, 0]\nclass = Buying'),
#  Text(1508.1081081081081, 1149.923076923077, 'Doors <= 0.5\ngini = 0.245\nsamples = 14\nvalue = [12, 0, 2, 0]\nclass = Buying'),
#  Text(1432.7027027027027, 940.846153846154, 'Persons <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 2, 0]\nclass = Doors'),
#  Text(1357.2972972972973, 731.769230769231, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Buying'),
#  Text(1508.1081081081081, 731.769230769231, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = Doors'),
#  Text(1583.5135135135135, 940.846153846154, 'gini = 0.0\nsamples = 11\nvalue = [11, 0, 0, 0]\nclass = Buying'),
#  Text(1922.8378378378377, 1149.923076923077, 'Buying <= 1.5\ngini = 0.557\nsamples = 25\nvalue = [6, 15, 4, 0]\nclass = Maintaince'),
#  Text(1734.3243243243244, 940.846153846154, 'Doors <= 0.5\ngini = 0.278\nsamples = 12\nvalue = [0, 10, 2, 0]\nclass = Maintaince'),
#  Text(1658.918918918919, 731.769230769231, 'Persons <= 1.5\ngini = 0.5\nsamples = 4\nvalue = [0, 2, 2, 0]\nclass = Maintaince'),
#  Text(1583.5135135135135, 522.6923076923076, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = Maintaince'),
#  Text(1734.3243243243244, 522.6923076923076, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = Doors'),
#  Text(1809.7297297297296, 731.769230769231, 'gini = 0.0\nsamples = 8\nvalue = [0, 8, 0, 0]\nclass = Maintaince'),
#  Text(2111.3513513513512, 940.846153846154, 'Maintaince <= 1.5\ngini = 0.615\nsamples = 13\nvalue = [6, 5, 2, 0]\nclass = Buying'),
#  Text(1960.5405405405404, 731.769230769231, 'Doors <= 0.5\ngini = 0.278\nsamples = 6\nvalue = [0, 5, 1, 0]\nclass = Maintaince'),
#  Text(1885.135135135135, 522.6923076923076, 'Persons <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0]\nclass = Maintaince'),
#  Text(1809.7297297297296, 313.61538461538476, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Maintaince'),
#  Text(1960.5405405405404, 313.61538461538476, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Doors'),
#  Text(2035.9459459459458, 522.6923076923076, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]\nclass = Maintaince'),
#  Text(2262.162162162162, 731.769230769231, 'Doors <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [6, 0, 1, 0]\nclass = Buying'),
#  Text(2186.7567567567567, 522.6923076923076, 'Persons <= 1.5\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0]\nclass = Buying'),
#  Text(2111.3513513513512, 313.61538461538476, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Buying'),
#  Text(2262.162162162162, 313.61538461538476, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Doors'),
#  Text(2337.5675675675675, 522.6923076923076, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0, 0]\nclass = Buying'),
#  Text(2412.972972972973, 1568.076923076923, 'Maintaince <= 0.5\ngini = 0.482\nsamples = 52\nvalue = [31, 0, 21, 0]\nclass = Buying'),
#  Text(2337.5675675675675, 1359.0, 'gini = 0.0\nsamples = 20\nvalue = [0, 0, 20, 0]\nclass = Doors'),
#  Text(2488.3783783783783, 1359.0, 'Doors <= 0.5\ngini = 0.061\nsamples = 32\nvalue = [31, 0, 1, 0]\nclass = Buying'),
#  Text(2412.972972972973, 1149.923076923077, 'Lug_boot <= 1.5\ngini = 0.198\nsamples = 9\nvalue = [8, 0, 1, 0]\nclass = Buying'),
#  Text(2337.5675675675675, 940.846153846154, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0]\nclass = Buying'),
#  Text(2488.3783783783783, 940.846153846154, 'Persons <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 1, 0]\nclass = Buying'),
#  Text(2412.972972972973, 731.769230769231, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Buying'),
#  Text(2563.7837837837837, 731.769230769231, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Doors'),
#  Text(2563.7837837837837, 1149.923076923077, 'gini = 0.0\nsamples = 23\nvalue = [23, 0, 0, 0]\nclass = Buying'),
#  Text(2714.5945945945946, 1986.2307692307693, 'Buying <= 0.5\ngini = 0.497\nsamples = 56\nvalue = [26, 0, 30, 0]\nclass = Doors'),
#  Text(2639.189189189189, 1777.1538461538462, 'gini = 0.0\nsamples = 17\nvalue = [0, 0, 17, 0]\nclass = Doors'),
#  Text(2790.0, 1777.1538461538462, 'Buying <= 2.5\ngini = 0.444\nsamples = 39\nvalue = [26, 0, 13, 0]\nclass = Buying'),
#  Text(2714.5945945945946, 1568.076923076923, 'Lug_boot <= 1.5\ngini = 0.133\nsamples = 28\nvalue = [26, 0, 2, 0]\nclass = Buying'),
#  Text(2639.189189189189, 1359.0, 'gini = 0.0\nsamples = 18\nvalue = [18, 0, 0, 0]\nclass = Buying'),
#  Text(2790.0, 1359.0, 'Doors <= 0.5\ngini = 0.32\nsamples = 10\nvalue = [8, 0, 2, 0]\nclass = Buying'),
#  Text(2714.5945945945946, 1149.923076923077, 'Persons <= 1.5\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 2, 0]\nclass = Doors'),
#  Text(2639.189189189189, 940.846153846154, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Buying'),
#  Text(2790.0, 940.846153846154, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = Doors'),
#  Text(2865.4054054054054, 1149.923076923077, 'gini = 0.0\nsamples = 7\nvalue = [7, 0, 0, 0]\nclass = Buying'),
#  Text(2865.4054054054054, 1568.076923076923, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0]\nclass = Doors'),
#  Text(4657.461993243243, 2195.3076923076924, 'Safety <= 1.5\ngini = 0.428\nsamples = 534\nvalue = [125, 26, 383, 0]\nclass = Doors'),
#  Text(4582.0565878378375, 1986.2307692307693, 'gini = 0.0\nsamples = 268\nvalue = [0, 0, 268, 0]\nclass = Doors'),
#  Text(4732.867398648648, 1986.2307692307693, 'Lug_boot <= 1.5\ngini = 0.583\nsamples = 266\nvalue = [125, 26, 115, 0]\nclass = Buying'),
#  Text(4111.951013513513, 1777.1538461538462, 'Buying <= 2.5\ngini = 0.563\nsamples = 179\nvalue = [105, 26, 48, 0]\nclass = Buying'),
#  Text(3473.3614864864862, 1568.076923076923, 'Buying <= 0.5\ngini = 0.516\nsamples = 134\nvalue = [87, 26, 21, 0]\nclass = Buying'),
#  Text(3091.6216216216217, 1359.0, 'Maintaince <= 2.5\ngini = 0.466\nsamples = 46\nvalue = [29, 0, 17, 0]\nclass = Buying'),
#  Text(3016.2162162162163, 1149.923076923077, 'Lug_boot <= 0.5\ngini = 0.313\nsamples = 36\nvalue = [29, 0, 7, 0]\nclass = Buying'),
#  Text(2940.810810810811, 940.846153846154, 'gini = 0.0\nsamples = 21\nvalue = [21, 0, 0, 0]\nclass = Buying'),
#  Text(3091.6216216216217, 940.846153846154, 'Doors <= 1.5\ngini = 0.498\nsamples = 15\nvalue = [8, 0, 7, 0]\nclass = Buying'),
#  Text(3016.2162162162163, 731.769230769231, 'Doors <= 0.5\ngini = 0.346\nsamples = 9\nvalue = [2, 0, 7, 0]\nclass = Doors'),
#  Text(2940.810810810811, 522.6923076923076, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0]\nclass = Doors'),
#  Text(3091.6216216216217, 522.6923076923076, 'Persons <= 1.5\ngini = 0.5\nsamples = 4\nvalue = [2, 0, 2, 0]\nclass = Buying'),
#  Text(3016.2162162162163, 313.61538461538476, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = Doors'),
#  Text(3167.027027027027, 313.61538461538476, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Buying'),
#  Text(3167.027027027027, 731.769230769231, 'gini = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0]\nclass = Buying'),
#  Text(3167.027027027027, 1149.923076923077, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0]\nclass = Doors'),
#  Text(3855.1013513513512, 1359.0, 'Maintaince <= 0.5\ngini = 0.476\nsamples = 88\nvalue = [58, 26, 4, 0]\nclass = Buying'),
#  Text(3468.6486486486488, 1149.923076923077, 'Doors <= 0.5\ngini = 0.087\nsamples = 22\nvalue = [21, 0, 1, 0]\nclass = Buying'),
#  Text(3393.2432432432433, 940.846153846154, 'Buying <= 1.5\ngini = 0.245\nsamples = 7\nvalue = [6, 0, 1, 0]\nclass = Buying'),
#  Text(3317.837837837838, 731.769230769231, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = Buying'),
#  Text(3468.6486486486488, 731.769230769231, 'Lug_boot <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 1, 0]\nclass = Buying'),
#  Text(3393.2432432432433, 522.6923076923076, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Buying'),
#  Text(3544.054054054054, 522.6923076923076, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Doors'),
#  Text(3544.054054054054, 940.846153846154, 'gini = 0.0\nsamples = 15\nvalue = [15, 0, 0, 0]\nclass = Buying'),
#  Text(4241.554054054054, 1149.923076923077, 'Maintaince <= 2.5\ngini = 0.528\nsamples = 66\nvalue = [37, 26, 3, 0]\nclass = Buying'),
#  Text(3958.7837837837837, 940.846153846154, 'Lug_boot <= 0.5\ngini = 0.478\nsamples = 43\nvalue = [17, 26, 0, 0]\nclass = Maintaince'),
#  Text(3770.27027027027, 731.769230769231, 'Maintaince <= 1.5\ngini = 0.32\nsamples = 20\nvalue = [4, 16, 0, 0]\nclass = Maintaince'),
#  Text(3694.8648648648646, 522.6923076923076, 'gini = 0.0\nsamples = 10\nvalue = [0, 10, 0, 0]\nclass = Maintaince'),
#  Text(3845.6756756756754, 522.6923076923076, 'Buying <= 1.5\ngini = 0.48\nsamples = 10\nvalue = [4, 6, 0, 0]\nclass = Maintaince'),
#  Text(3770.27027027027, 313.61538461538476, 'gini = 0.0\nsamples = 6\nvalue = [0, 6, 0, 0]\nclass = Maintaince'),
#  Text(3921.081081081081, 313.61538461538476, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = Buying'),
#  Text(4147.2972972972975, 731.769230769231, 'Doors <= 0.5\ngini = 0.491\nsamples = 23\nvalue = [13, 10, 0, 0]\nclass = Buying'),
#  Text(4071.8918918918916, 522.6923076923076, 'gini = 0.0\nsamples = 7\nvalue = [7, 0, 0, 0]\nclass = Buying'),
#  Text(4222.7027027027025, 522.6923076923076, 'Maintaince <= 1.5\ngini = 0.469\nsamples = 16\nvalue = [6, 10, 0, 0]\nclass = Maintaince'),
#  Text(4071.8918918918916, 313.61538461538476, 'Doors <= 1.5\ngini = 0.32\nsamples = 10\nvalue = [2, 8, 0, 0]\nclass = Maintaince'),
#  Text(3996.4864864864862, 104.53846153846189, 'gini = 0.5\nsamples = 4\nvalue = [2, 2, 0, 0]\nclass = Buying'),
#  Text(4147.2972972972975, 104.53846153846189, 'gini = 0.0\nsamples = 6\nvalue = [0, 6, 0, 0]\nclass = Maintaince'),
#  Text(4373.513513513513, 313.61538461538476, 'Buying <= 1.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2, 0, 0]\nclass = Buying'),
#  Text(4298.108108108108, 104.53846153846189, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = Maintaince'),
#  Text(4448.918918918919, 104.53846153846189, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = Buying'),
#  Text(4524.324324324324, 940.846153846154, 'Doors <= 0.5\ngini = 0.227\nsamples = 23\nvalue = [20, 0, 3, 0]\nclass = Buying'),
#  Text(4448.918918918919, 731.769230769231, 'Lug_boot <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [4, 0, 3, 0]\nclass = Buying'),
#  Text(4373.513513513513, 522.6923076923076, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = Buying'),
#  Text(4524.324324324324, 522.6923076923076, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]\nclass = Doors'),
#  Text(4599.72972972973, 731.769230769231, 'gini = 0.0\nsamples = 16\nvalue = [16, 0, 0, 0]\nclass = Buying'),
#  Text(4750.540540540541, 1568.076923076923, 'Maintaince <= 0.5\ngini = 0.48\nsamples = 45\nvalue = [18, 0, 27, 0]\nclass = Doors'),
#  Text(4675.135135135135, 1359.0, 'gini = 0.0\nsamples = 14\nvalue = [0, 0, 14, 0]\nclass = Doors'),
#  Text(4825.945945945946, 1359.0, 'Maintaince <= 2.5\ngini = 0.487\nsamples = 31\nvalue = [18, 0, 13, 0]\nclass = Buying'),
#  Text(4750.540540540541, 1149.923076923077, 'Lug_boot <= 0.5\ngini = 0.245\nsamples = 21\nvalue = [18, 0, 3, 0]\nclass = Buying'),
#  Text(4675.135135135135, 940.846153846154, 'gini = 0.0\nsamples = 13\nvalue = [13, 0, 0, 0]\nclass = Buying'),
#  Text(4825.945945945946, 940.846153846154, 'Doors <= 1.5\ngini = 0.469\nsamples = 8\nvalue = [5, 0, 3, 0]\nclass = Buying'),
#  Text(4750.540540540541, 731.769230769231, 'Maintaince <= 1.5\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 3, 0]\nclass = Doors'),
#  Text(4675.135135135135, 522.6923076923076, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]\nclass = Doors'),
#  Text(4825.945945945946, 522.6923076923076, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Buying'),
#  Text(4901.351351351351, 731.769230769231, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = Buying'),
#  Text(4901.351351351351, 1149.923076923077, 'gini = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0]\nclass = Doors'),
#  Text(5353.783783783783, 1777.1538461538462, 'Buying <= 0.5\ngini = 0.354\nsamples = 87\nvalue = [20, 0, 67, 0]\nclass = Doors'),
#  Text(5278.378378378378, 1568.076923076923, 'gini = 0.0\nsamples = 24\nvalue = [0, 0, 24, 0]\nclass = Doors'),
#  Text(5429.189189189189, 1568.076923076923, 'Buying <= 2.5\ngini = 0.433\nsamples = 63\nvalue = [20, 0, 43, 0]\nclass = Doors'),
#  Text(5353.783783783783, 1359.0, 'Maintaince <= 2.5\ngini = 0.5\nsamples = 40\nvalue = [20, 0, 20, 0]\nclass = Buying'),
#  Text(5278.378378378378, 1149.923076923077, 'Doors <= 0.5\ngini = 0.428\nsamples = 29\nvalue = [20, 0, 9, 0]\nclass = Buying'),
#  Text(5127.5675675675675, 940.846153846154, 'Persons <= 1.5\ngini = 0.278\nsamples = 6\nvalue = [1, 0, 5, 0]\nclass = Doors'),
#  Text(5052.162162162162, 731.769230769231, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Buying'),
#  Text(5202.9729729729725, 731.769230769231, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0]\nclass = Doors'),
#  Text(5429.189189189189, 940.846153846154, 'Maintaince <= 0.5\ngini = 0.287\nsamples = 23\nvalue = [19, 0, 4, 0]\nclass = Buying'),
#  Text(5353.783783783783, 731.769230769231, 'Buying <= 1.5\ngini = 0.49\nsamples = 7\nvalue = [3, 0, 4, 0]\nclass = Doors'),
#  Text(5278.378378378378, 522.6923076923076, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = Buying'),
#  Text(5429.189189189189, 522.6923076923076, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0]\nclass = Doors'),
#  Text(5504.594594594594, 731.769230769231, 'gini = 0.0\nsamples = 16\nvalue = [16, 0, 0, 0]\nclass = Buying'),
#  Text(5429.189189189189, 1149.923076923077, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0]\nclass = Doors'),
#  Text(5504.594594594594, 1359.0, 'gini = 0.0\nsamples = 23\nvalue = [0, 0, 23, 0]\nclass = Doors')]

# %%
from sklearn.metrics import plot_confusion_matrix

plot_confusion_matrix(dt_clf, X_test, y_test, display_labels=["unacc","acc","good","vgood"])

# %%
predictions = dt_clf.predict(X_test)

# %%
accuracy = (predictions==y_test).sum()/(len(y_test))
accuracy
# Out:
# 0.9788053949903661

# %%
accuracy = accuracy*100
accuracy
# Out:
# 97.88053949903662

# %%
print('Training set score: {:.4f}'.format(dt_clf.score(X_train, y_train)))

print('Test set score: {:.4f}'.format(dt_clf.score(X_test, y_test)))
# Out:
# Training set score: 0.9983
# Test set score: 0.9788

# %%
from sklearn.metrics import accuracy_score

print('Model accuracy score with criterion gini index: {0:0.4f}%'. format(accuracy_score(y_test,predictions)*100))
# Out:
# Model accuracy score with criterion gini index: 97.4952%

# %%
dt_clf1 = DecisionTreeClassifier(criterion='entropy',random_state=42,max_depth=12)
dt_clf1 = dt_clf.fit(X_train, y_train)

# %%
plt.figure(figsize=(100, 50))
plot_tree(dt_clf1,
          filled=True,
          rounded=True,
          class_names=["Buying",
"Maintaince",
"Doors",
"Persons",
"Lug_boot",
"Safety"],
         feature_names=X.columns)
# Out:
# [Text(3029.08447265625, 2613.4615384615386, 'Persons <= 0.5\nentropy = 1.204\nsamples = 1209\nvalue = [269, 48, 847, 45]\nclass = Doors'),
#  Text(2941.89697265625, 2404.3846153846152, 'entropy = 0.0\nsamples = 404\nvalue = [0, 0, 404, 0]\nclass = Doors'),
#  Text(3116.27197265625, 2404.3846153846152, 'Safety <= 0.5\nentropy = 1.478\nsamples = 805\nvalue = [269, 48, 443, 45]\nclass = Doors'),
#  Text(1662.01171875, 2195.3076923076924, 'Buying <= 2.5\nentropy = 1.691\nsamples = 271\nvalue = [144, 22, 60, 45]\nclass = Buying'),
#  Text(882.7734375, 1986.2307692307693, 'Buying <= 0.5\nentropy = 1.688\nsamples = 208\nvalue = [113, 22, 28, 45]\nclass = Buying'),
#  Text(348.75, 1777.1538461538462, 'Maintaince <= 2.5\nentropy = 0.847\nsamples = 73\nvalue = [53, 0, 20, 0]\nclass = Buying'),
#  Text(261.5625, 1568.076923076923, 'Doors <= 0.5\nentropy = 0.301\nsamples = 56\nvalue = [53, 0, 3, 0]\nclass = Buying'),
#  Text(174.375, 1359.0, 'Lug_boot <= 1.5\nentropy = 0.65\nsamples = 18\nvalue = [15, 0, 3, 0]\nclass = Buying'),
#  Text(87.1875, 1149.923076923077, 'entropy = 0.0\nsamples = 12\nvalue = [12, 0, 0, 0]\nclass = Buying'),
#  Text(261.5625, 1149.923076923077, 'Persons <= 1.5\nentropy = 1.0\nsamples = 6\nvalue = [3, 0, 3, 0]\nclass = Buying'),
#  Text(174.375, 940.846153846154, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = Buying'),
#  Text(348.75, 940.846153846154, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]\nclass = Doors'),
#  Text(348.75, 1359.0, 'entropy = 0.0\nsamples = 38\nvalue = [38, 0, 0, 0]\nclass = Buying'),
#  Text(435.9375, 1568.076923076923, 'entropy = 0.0\nsamples = 17\nvalue = [0, 0, 17, 0]\nclass = Doors'),
#  Text(1416.796875, 1777.1538461538462, 'Lug_boot <= 1.5\nentropy = 1.716\nsamples = 135\nvalue = [60, 22, 8, 45]\nclass = Buying'),
#  Text(1002.65625, 1568.076923076923, 'Maintaince <= 2.5\nentropy = 1.313\nsamples = 86\nvalue = [34, 7, 0, 45]\nclass = Persons'),
#  Text(915.46875, 1359.0, 'Maintaince <= 0.5\nentropy = 1.223\nsamples = 68\nvalue = [16, 7, 0, 45]\nclass = Persons'),
#  Text(610.3125, 1149.923076923077, 'Buying <= 1.5\nentropy = 0.946\nsamples = 22\nvalue = [14, 0, 0, 8]\nclass = Buying'),
#  Text(523.125, 940.846153846154, 'Lug_boot <= 0.5\nentropy = 0.845\nsamples = 11\nvalue = [3, 0, 0, 8]\nclass = Persons'),
#  Text(435.9375, 731.769230769231, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 0, 5]\nclass = Persons'),
#  Text(610.3125, 731.769230769231, 'Doors <= 0.5\nentropy = 1.0\nsamples = 6\nvalue = [3, 0, 0, 3]\nclass = Buying'),
#  Text(523.125, 522.6923076923076, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Buying'),
#  Text(697.5, 522.6923076923076, 'Doors <= 2.0\nentropy = 0.811\nsamples = 4\nvalue = [1, 0, 0, 3]\nclass = Persons'),
#  Text(610.3125, 313.61538461538476, 'Persons <= 1.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 0, 0, 1]\nclass = Buying'),
#  Text(523.125, 104.53846153846189, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Buying'),
#  Text(697.5, 104.53846153846189, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Persons'),
#  Text(784.6875, 313.61538461538476, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2]\nclass = Persons'),
#  Text(697.5, 940.846153846154, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0, 0, 0]\nclass = Buying'),
#  Text(1220.625, 1149.923076923077, 'Lug_boot <= 0.5\nentropy = 0.863\nsamples = 46\nvalue = [2, 7, 0, 37]\nclass = Persons'),
#  Text(1133.4375, 940.846153846154, 'entropy = 0.0\nsamples = 23\nvalue = [0, 0, 0, 23]\nclass = Persons'),
#  Text(1307.8125, 940.846153846154, 'Doors <= 1.5\nentropy = 1.265\nsamples = 23\nvalue = [2, 7, 0, 14]\nclass = Persons'),
#  Text(1220.625, 731.769230769231, 'Buying <= 1.5\nentropy = 1.157\nsamples = 10\nvalue = [2, 7, 0, 1]\nclass = Maintaince'),
#  Text(1046.25, 522.6923076923076, 'Doors <= 0.5\nentropy = 0.65\nsamples = 6\nvalue = [0, 5, 0, 1]\nclass = Maintaince'),
#  Text(959.0625, 313.61538461538476, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0]\nclass = Maintaince'),
#  Text(1133.4375, 313.61538461538476, 'Persons <= 1.5\nentropy = 1.0\nsamples = 2\nvalue = [0, 1, 0, 1]\nclass = Maintaince'),
#  Text(1046.25, 104.53846153846189, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Maintaince'),
#  Text(1220.625, 104.53846153846189, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1]\nclass = Persons'),
#  Text(1395.0, 522.6923076923076, 'Maintaince <= 1.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2, 0, 0]\nclass = Buying'),
#  Text(1307.8125, 313.61538461538476, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = Maintaince'),
#  Text(1482.1875, 313.61538461538476, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Buying'),
#  Text(1395.0, 731.769230769231, 'entropy = 0.0\nsamples = 13\nvalue = [0, 0, 0, 13]\nclass = Persons'),
#  Text(1089.84375, 1359.0, 'entropy = 0.0\nsamples = 18\nvalue = [18, 0, 0, 0]\nclass = Buying'),
#  Text(1830.9375, 1568.076923076923, 'Doors <= 0.5\nentropy = 1.435\nsamples = 49\nvalue = [26, 15, 8, 0]\nclass = Buying'),
#  Text(1656.5625, 1359.0, 'Persons <= 1.5\nentropy = 1.414\nsamples = 14\nvalue = [3, 3, 8, 0]\nclass = Doors'),
#  Text(1569.375, 1149.923076923077, 'Maintaince <= 0.5\nentropy = 1.0\nsamples = 6\nvalue = [3, 3, 0, 0]\nclass = Buying'),
#  Text(1482.1875, 940.846153846154, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Buying'),
#  Text(1656.5625, 940.846153846154, 'Buying <= 1.5\nentropy = 0.971\nsamples = 5\nvalue = [2, 3, 0, 0]\nclass = Maintaince'),
#  Text(1569.375, 731.769230769231, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = Maintaince'),
#  Text(1743.75, 731.769230769231, 'Maintaince <= 1.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 1, 0, 0]\nclass = Buying'),
#  Text(1656.5625, 522.6923076923076, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0]\nclass = Maintaince'),
#  Text(1830.9375, 522.6923076923076, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Buying'),
#  Text(1743.75, 1149.923076923077, 'entropy = 0.0\nsamples = 8\nvalue = [0, 0, 8, 0]\nclass = Doors'),
#  Text(2005.3125, 1359.0, 'Maintaince <= 0.5\nentropy = 0.928\nsamples = 35\nvalue = [23, 12, 0, 0]\nclass = Buying'),
#  Text(1918.125, 1149.923076923077, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0, 0, 0]\nclass = Buying'),
#  Text(2092.5, 1149.923076923077, 'Maintaince <= 1.5\nentropy = 1.0\nsamples = 24\nvalue = [12, 12, 0, 0]\nclass = Buying'),
#  Text(2005.3125, 940.846153846154, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7, 0, 0]\nclass = Maintaince'),
#  Text(2179.6875, 940.846153846154, 'Buying <= 1.5\nentropy = 0.874\nsamples = 17\nvalue = [12, 5, 0, 0]\nclass = Buying'),
#  Text(2092.5, 731.769230769231, 'Maintaince <= 2.5\nentropy = 0.991\nsamples = 9\nvalue = [4, 5, 0, 0]\nclass = Maintaince'),
#  Text(2005.3125, 522.6923076923076, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0]\nclass = Maintaince'),
#  Text(2179.6875, 522.6923076923076, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = Buying'),
#  Text(2266.875, 731.769230769231, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0, 0, 0]\nclass = Buying'),
#  Text(2441.25, 1986.2307692307693, 'Maintaince <= 0.5\nentropy = 1.0\nsamples = 63\nvalue = [31, 0, 32, 0]\nclass = Doors'),
#  Text(2354.0625, 1777.1538461538462, 'entropy = 0.0\nsamples = 20\nvalue = [0, 0, 20, 0]\nclass = Doors'),
#  Text(2528.4375, 1777.1538461538462, 'Maintaince <= 2.5\nentropy = 0.854\nsamples = 43\nvalue = [31, 0, 12, 0]\nclass = Buying'),
#  Text(2441.25, 1568.076923076923, 'Doors <= 0.5\nentropy = 0.201\nsamples = 32\nvalue = [31, 0, 1, 0]\nclass = Buying'),
#  Text(2354.0625, 1359.0, 'Lug_boot <= 1.5\nentropy = 0.503\nsamples = 9\nvalue = [8, 0, 1, 0]\nclass = Buying'),
#  Text(2266.875, 1149.923076923077, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0]\nclass = Buying'),
#  Text(2441.25, 1149.923076923077, 'Persons <= 1.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 0, 1, 0]\nclass = Buying'),
#  Text(2354.0625, 940.846153846154, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Buying'),
#  Text(2528.4375, 940.846153846154, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Doors'),
#  Text(2528.4375, 1359.0, 'entropy = 0.0\nsamples = 23\nvalue = [23, 0, 0, 0]\nclass = Buying'),
#  Text(2615.625, 1568.076923076923, 'entropy = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0]\nclass = Doors'),
#  Text(4570.5322265625, 2195.3076923076924, 'Safety <= 1.5\nentropy = 1.047\nsamples = 534\nvalue = [125, 26, 383, 0]\nclass = Doors'),
#  Text(4483.3447265625, 1986.2307692307693, 'entropy = 0.0\nsamples = 268\nvalue = [0, 0, 268, 0]\nclass = Doors'),
#  Text(4657.7197265625, 1986.2307692307693, 'Lug_boot <= 1.5\nentropy = 1.363\nsamples = 266\nvalue = [125, 26, 115, 0]\nclass = Buying'),
#  Text(3997.001953125, 1777.1538461538462, 'Buying <= 2.5\nentropy = 1.365\nsamples = 179\nvalue = [105, 26, 48, 0]\nclass = Buying'),
#  Text(3373.06640625, 1568.076923076923, 'Buying <= 0.5\nentropy = 1.283\nsamples = 134\nvalue = [87, 26, 21, 0]\nclass = Buying'),
#  Text(2877.1875, 1359.0, 'Maintaince <= 2.5\nentropy = 0.95\nsamples = 46\nvalue = [29, 0, 17, 0]\nclass = Buying'),
#  Text(2790.0, 1149.923076923077, 'Lug_boot <= 0.5\nentropy = 0.711\nsamples = 36\nvalue = [29, 0, 7, 0]\nclass = Buying'),
#  Text(2702.8125, 940.846153846154, 'entropy = 0.0\nsamples = 21\nvalue = [21, 0, 0, 0]\nclass = Buying'),
#  Text(2877.1875, 940.846153846154, 'Doors <= 1.5\nentropy = 0.997\nsamples = 15\nvalue = [8, 0, 7, 0]\nclass = Buying'),
#  Text(2790.0, 731.769230769231, 'Doors <= 0.5\nentropy = 0.764\nsamples = 9\nvalue = [2, 0, 7, 0]\nclass = Doors'),
#  Text(2702.8125, 522.6923076923076, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0]\nclass = Doors'),
#  Text(2877.1875, 522.6923076923076, 'Persons <= 1.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 0, 2, 0]\nclass = Buying'),
#  Text(2790.0, 313.61538461538476, 'entropy = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]\nclass = Doors'),
#  Text(2964.375, 313.61538461538476, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Buying'),
#  Text(2964.375, 731.769230769231, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0, 0, 0]\nclass = Buying'),
#  Text(2964.375, 1149.923076923077, 'entropy = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0]\nclass = Doors'),
#  Text(3868.9453125, 1359.0, 'Maintaince <= 2.5\nentropy = 1.119\nsamples = 88\nvalue = [58, 26, 4, 0]\nclass = Buying'),
#  Text(3465.703125, 1149.923076923077, 'Maintaince <= 0.5\nentropy = 1.074\nsamples = 65\nvalue = [38, 26, 1, 0]\nclass = Buying'),
#  Text(3225.9375, 940.846153846154, 'Doors <= 0.5\nentropy = 0.267\nsamples = 22\nvalue = [21, 0, 1, 0]\nclass = Buying'),
#  Text(3138.75, 731.769230769231, 'Lug_boot <= 0.5\nentropy = 0.592\nsamples = 7\nvalue = [6, 0, 1, 0]\nclass = Buying'),
#  Text(3051.5625, 522.6923076923076, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = Buying'),
#  Text(3225.9375, 522.6923076923076, 'Buying <= 1.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 0, 1, 0]\nclass = Buying'),
#  Text(3138.75, 313.61538461538476, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0]\nclass = Buying'),
#  Text(3313.125, 313.61538461538476, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0]\nclass = Doors'),
#  Text(3313.125, 731.769230769231, 'entropy = 0.0\nsamples = 15\nvalue = [15, 0, 0, 0]\nclass = Buying'),
#  Text(3705.46875, 940.846153846154, 'Lug_boot <= 0.5\nentropy = 0.968\nsamples = 43\nvalue = [17, 26, 0, 0]\nclass = Maintaince'),
#  Text(3487.5, 731.769230769231, 'Buying <= 1.5\nentropy = 0.722\nsamples = 20\nvalue = [4, 16, 0, 0]\nclass = Maintaince'),
#  Text(3400.3125, 522.6923076923076, 'entropy = 0.0\nsamples = 10\nvalue = [0, 10, 0, 0]\nclass = Maintaince'),
#  Text(3574.6875, 522.6923076923076, 'Maintaince <= 1.5\nentropy = 0.971\nsamples = 10\nvalue = [4, 6, 0, 0]\nclass = Maintaince'),
#  Text(3487.5, 313.61538461538476, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6, 0, 0]\nclass = Maintaince'),
#  Text(3661.875, 313.61538461538476, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = Buying'),
#  Text(3923.4375, 731.769230769231, 'Doors <= 0.5\nentropy = 0.988\nsamples = 23\nvalue = [13, 10, 0, 0]\nclass = Buying'),
#  Text(3836.25, 522.6923076923076, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0, 0, 0]\nclass = Buying'),
#  Text(4010.625, 522.6923076923076, 'Maintaince <= 1.5\nentropy = 0.954\nsamples = 16\nvalue = [6, 10, 0, 0]\nclass = Maintaince'),
#  Text(3836.25, 313.61538461538476, 'Doors <= 1.5\nentropy = 0.722\nsamples = 10\nvalue = [2, 8, 0, 0]\nclass = Maintaince'),
#  Text(3749.0625, 104.53846153846189, 'entropy = 1.0\nsamples = 4\nvalue = [2, 2, 0, 0]\nclass = Buying'),
#  Text(3923.4375, 104.53846153846189, 'entropy = 0.0\nsamples = 6\nvalue = [0, 6, 0, 0]\nclass = Maintaince'),
#  Text(4185.0, 313.61538461538476, 'Buying <= 1.5\nentropy = 0.918\nsamples = 6\nvalue = [4, 2, 0, 0]\nclass = Buying'),
#  Text(4097.8125, 104.53846153846189, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0]\nclass = Maintaince'),
#  Text(4272.1875, 104.53846153846189, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = Buying'),
#  Text(4272.1875, 1149.923076923077, 'Doors <= 0.5\nentropy = 0.559\nsamples = 23\nvalue = [20, 0, 3, 0]\nclass = Buying'),
#  Text(4185.0, 940.846153846154, 'Lug_boot <= 0.5\nentropy = 0.985\nsamples = 7\nvalue = [4, 0, 3, 0]\nclass = Buying'),
#  Text(4097.8125, 731.769230769231, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = Buying'),
#  Text(4272.1875, 731.769230769231, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]\nclass = Doors'),
#  Text(4359.375, 940.846153846154, 'entropy = 0.0\nsamples = 16\nvalue = [16, 0, 0, 0]\nclass = Buying'),
#  Text(4620.9375, 1568.076923076923, 'Maintaince <= 0.5\nentropy = 0.971\nsamples = 45\nvalue = [18, 0, 27, 0]\nclass = Doors'),
#  Text(4533.75, 1359.0, 'entropy = 0.0\nsamples = 14\nvalue = [0, 0, 14, 0]\nclass = Doors'),
#  Text(4708.125, 1359.0, 'Maintaince <= 2.5\nentropy = 0.981\nsamples = 31\nvalue = [18, 0, 13, 0]\nclass = Buying'),
#  Text(4620.9375, 1149.923076923077, 'Lug_boot <= 0.5\nentropy = 0.592\nsamples = 21\nvalue = [18, 0, 3, 0]\nclass = Buying'),
#  Text(4533.75, 940.846153846154, 'entropy = 0.0\nsamples = 13\nvalue = [13, 0, 0, 0]\nclass = Buying'),
#  Text(4708.125, 940.846153846154, 'Doors <= 1.5\nentropy = 0.954\nsamples = 8\nvalue = [5, 0, 3, 0]\nclass = Buying'),
#  Text(4620.9375, 731.769230769231, 'Maintaince <= 1.5\nentropy = 0.811\nsamples = 4\nvalue = [1, 0, 3, 0]\nclass = Doors'),
#  Text(4533.75, 522.6923076923076, 'entropy = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0]\nclass = Doors'),
#  Text(4708.125, 522.6923076923076, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Buying'),
#  Text(4795.3125, 731.769230769231, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0]\nclass = Buying'),
#  Text(4795.3125, 1149.923076923077, 'entropy = 0.0\nsamples = 10\nvalue = [0, 0, 10, 0]\nclass = Doors'),
#  Text(5318.4375, 1777.1538461538462, 'Buying <= 0.5\nentropy = 0.778\nsamples = 87\nvalue = [20, 0, 67, 0]\nclass = Doors'),
#  Text(5231.25, 1568.076923076923, 'entropy = 0.0\nsamples = 24\nvalue = [0, 0, 24, 0]\nclass = Doors'),
#  Text(5405.625, 1568.076923076923, 'Buying <= 2.5\nentropy = 0.902\nsamples = 63\nvalue = [20, 0, 43, 0]\nclass = Doors'),
#  Text(5318.4375, 1359.0, 'Maintaince <= 2.5\nentropy = 1.0\nsamples = 40\nvalue = [20, 0, 20, 0]\nclass = Buying'),
#  Text(5231.25, 1149.923076923077, 'Doors <= 0.5\nentropy = 0.894\nsamples = 29\nvalue = [20, 0, 9, 0]\nclass = Buying'),
#  Text(5056.875, 940.846153846154, 'Persons <= 1.5\nentropy = 0.65\nsamples = 6\nvalue = [1, 0, 5, 0]\nclass = Doors'),
#  Text(4969.6875, 731.769230769231, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0]\nclass = Buying'),
#  Text(5144.0625, 731.769230769231, 'entropy = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0]\nclass = Doors'),
#  Text(5405.625, 940.846153846154, 'Maintaince <= 0.5\nentropy = 0.667\nsamples = 23\nvalue = [19, 0, 4, 0]\nclass = Buying'),
#  Text(5318.4375, 731.769230769231, 'Buying <= 1.5\nentropy = 0.985\nsamples = 7\nvalue = [3, 0, 4, 0]\nclass = Doors'),
#  Text(5231.25, 522.6923076923076, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0]\nclass = Buying'),
#  Text(5405.625, 522.6923076923076, 'entropy = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0]\nclass = Doors'),
#  Text(5492.8125, 731.769230769231, 'entropy = 0.0\nsamples = 16\nvalue = [16, 0, 0, 0]\nclass = Buying'),
#  Text(5405.625, 1149.923076923077, 'entropy = 0.0\nsamples = 11\nvalue = [0, 0, 11, 0]\nclass = Doors'),
#  Text(5492.8125, 1359.0, 'entropy = 0.0\nsamples = 23\nvalue = [0, 0, 23, 0]\nclass = Doors')]

# %%
plot_confusion_matrix(dt_clf1, X_test, y_test, display_labels=["unacc","acc","good","vgood"])

# %%
prediction = dt_clf1.predict(X_test)

# %%
accuracys = (prediction==y_test).sum()/(len(y_test))
accuracys
# Out:
# 0.9749518304431599

# %%
print('Training set score: {:.4f}'.format(dt_clf1.score(X_train, y_train)))

print('Test set score: {:.4f}'.format(dt_clf1.score(X_test, y_test)))
# Out:
# Training set score: 0.9983
# Test set score: 0.9750

# %%
print('Model accuracy score with criterion entropy index: {0:0.4f}%'. format(accuracy_score(y_test,prediction)*100))
# Out:
# Model accuracy score with criterion entropy index: 97.4952%
